# %%
# %cd libraries
import LOTlib3
# Out:
# /Users/meilongzhang/knightlab/codet5/libraries

# %%
from LOTlib3.Hypotheses.LOTHypothesis import LOTHypothesis
from LOTlib3.DataAndObjects import FunctionData, Obj

# %%
from LOTlib3.DefaultGrammars import DNF
from LOTlib3.Miscellaneous import q, random
from LOTlib3.Grammar import Grammar

# %%
DEFAULT_FEATURE_WEIGHT = 5
grammar = Grammar()
grammar.add_rule('START', '', ['DISJ'], 1.0)
grammar.add_rule('START', '', ['PRE-PREDICATE'], DEFAULT_FEATURE_WEIGHT)
grammar.add_rule('START', 'True', None, DEFAULT_FEATURE_WEIGHT)
grammar.add_rule('START', 'False', None, DEFAULT_FEATURE_WEIGHT)

grammar.add_rule('DISJ', '',     ['CONJ'], 1.0)
grammar.add_rule('DISJ', '',     ['PRE-PREDICATE'], DEFAULT_FEATURE_WEIGHT)
grammar.add_rule('DISJ', '(%s or %s)',  ['PRE-PREDICATE', 'DISJ'], 1.0)

grammar.add_rule('CONJ', '',     ['PRE-PREDICATE'], DEFAULT_FEATURE_WEIGHT)
grammar.add_rule('CONJ', '(%s and %s)', ['PRE-PREDICATE', 'CONJ'], 1.0)

# A pre-predicate is how we treat negation
grammar.add_rule('PRE-PREDICATE', 'not (%s)', ['PREDICATE'], DEFAULT_FEATURE_WEIGHT)
grammar.add_rule('PRE-PREDICATE', '',     ['PREDICATE'], DEFAULT_FEATURE_WEIGHT)
# Out:
# PRE-PREDICATE -> ['PREDICATE']	w/ p=5.0

# %%
#grammar.add_rule('PREDICATE', 'is_color_', ['x', 'COLOR'], 1.0)
#grammar.add_rule('PREDICATE', 'is_shape_', ['x', 'SHAPE'], 1.0)
grammar.add_rule('PREDICATE', "x['color']==%s", ['COLOR'], 1.0)
grammar.add_rule('PREDICATE', "x['shape']==%s", ['SHAPE'], 1.0)

# Some colors/shapes each (for this simple demo)
# These are written in quotes so they can be evaled
grammar.add_rule('COLOR', q('red'), None, 1.0)
grammar.add_rule('COLOR', q('blue'), None, 1.0)
grammar.add_rule('COLOR', q('green'), None, 1.0)


grammar.add_rule('SHAPE', q('square'), None, 1.0)
grammar.add_rule('SHAPE', q('circle'), None, 1.0)
grammar.add_rule('SHAPE', q('triangle'), None, 1.0)
# Out:
# SHAPE -> 'triangle'	w/ p=1.0

# %%
rules = {i: set() for i in range(15)}
for _ in range(100000):
    #rule = grammar.generate()
    #log_prob = grammar.log_probability(rule)
    rule = LOTHypothesis(grammar=grammar)
    depth = rule.value.depth() #rule.depth()
    rules[depth].add(rule)

# %%
rules = {depth: list(depth_rules) for depth, depth_rules in rules.items()}

# %%
colors = ['red', 'blue', 'green']
shapes = ['circle', 'square', 'triangle']
all_stimuli = []

for color in colors:
    for shape in shapes:
        all_stimuli.append({'shape':shape, 'color':color})

# %%
for stim in all_stimuli:
    result = test(stim)
    print(stim, result)
# Out:
# {'shape': 'circle', 'color': 'red'} False
# {'shape': 'square', 'color': 'red'} True
# {'shape': 'triangle', 'color': 'red'} True
# {'shape': 'circle', 'color': 'blue'} False
# {'shape': 'square', 'color': 'blue'} True
# {'shape': 'triangle', 'color': 'blue'} True
# {'shape': 'circle', 'color': 'green'} False
# {'shape': 'square', 'color': 'green'} True
# {'shape': 'triangle', 'color': 'green'} True

# %%
def make_training_example(rule_string, stimulus_list, output_list):
    prompt = "Write a lambda expression in Python that transforms the elements of input into the elements of output." +
             f"input = {stimulus_list} \n output = {output_list}"
    rule = rule_string
    return prompt, rule
# Out:
# lambda x: (x['shape']=='square' or x['shape']=='triangle')

# %% [markdown]
# # TO DO
#
# Sample 100 rules that differ in depth (maybe sample from a gaussian esstimated from the depth counts, so mean depth is sampled most, very short and very long programs sampled less often)
#
# For each rule, create training examples where the input is some description of the task, a list of stimuli, and a list of outputs. Number of stimuli in each training example should draw from some random number 1-15, and the actual stimuli should be saampled randomly from all stimuli.
#
# For each rule, you might want to generate several 'traning examples' with the same rule but differing number of input stimuli, so thaat it knows to generalize
#
# 1. Determine rule
# 2. Determine number of stimuli
# 3. Determine actual stimuli
#
# "Write a function" "Write a lambda expression that, when applied to the elements of input, generates the elements of output"

# %%
import matplotlib.pyplot as plt

# %%
rules
# Out:
# {0: [lambda x: True, lambda x: False],
#  1: [],
#  2: [],
#  3: [lambda x: x['color']=='red',
#   lambda x: x['shape']=='triangle',
#   lambda x: not (x['shape']=='triangle'),
#   lambda x: not (x['shape']=='square'),
#   lambda x: x['color']=='blue',
#   lambda x: x['shape']=='square',
#   lambda x: x['shape']=='circle',
#   lambda x: x['color']=='green',
#   lambda x: not (x['color']=='green'),
#   lambda x: not (x['shape']=='circle'),
#   lambda x: not (x['color']=='red'),
#   lambda x: not (x['color']=='blue')],
#  4: [lambda x: x['shape']=='triangle',
#   lambda x: x['color']=='red',
#   lambda x: not (x['shape']=='triangle'),
#   lambda x: not (x['shape']=='square'),
#   lambda x: x['color']=='blue',
#   lambda x: x['shape']=='square',
#   lambda x: x['shape']=='circle',
#   lambda x: x['color']=='green',
#   lambda x: not (x['color']=='green'),
#   lambda x: not (x['shape']=='circle'),
#   lambda x: not (x['color']=='red'),
#   lambda x: not (x['color']=='blue')],
#  5: [lambda x: (x['shape']=='square' or x['shape']=='triangle'),
#   lambda x: (not (x['color']=='green') or x['color']=='red'),
#   lambda x: (x['color']=='green' or x['color']=='red'),
#   lambda x: (x['color']=='green' or not (x['color']=='blue')),
#   lambda x: (not (x['color']=='red') or x['color']=='green'),
#   lambda x: (not (x['shape']=='circle') or x['color']=='blue'),
#   lambda x: (x['shape']=='square' or not (x['color']=='red')),
#   lambda x: (not (x['shape']=='square') or not (x['color']=='green')),
#   lambda x: (not (x['shape']=='circle') or not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='circle') or x['shape']=='circle'),
#   lambda x: (not (x['shape']=='square') or x['color']=='green'),
#   lambda x: (not (x['color']=='blue') or x['shape']=='square'),
#   lambda x: (x['shape']=='square' or not (x['shape']=='circle')),
#   lambda x: (x['shape']=='circle' or not (x['color']=='red')),
#   lambda x: (not (x['shape']=='triangle') or not (x['shape']=='circle')),
#   lambda x: (not (x['color']=='blue') or x['shape']=='triangle'),
#   lambda x: (x['color']=='blue' or not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='circle') or not (x['color']=='red')),
#   lambda x: (not (x['shape']=='triangle') or not (x['shape']=='square')),
#   lambda x: not (x['color']=='red'),
#   lambda x: (not (x['color']=='red') or not (x['shape']=='triangle')),
#   lambda x: (not (x['color']=='red') or x['color']=='blue'),
#   lambda x: (not (x['shape']=='triangle') or not (x['color']=='green')),
#   lambda x: (not (x['color']=='green') or x['color']=='green'),
#   lambda x: (not (x['color']=='green') or x['shape']=='square'),
#   lambda x: (not (x['color']=='red') or not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='circle') or not (x['color']=='green')),
#   lambda x: (x['color']=='blue' or x['shape']=='triangle'),
#   lambda x: (x['color']=='blue' or not (x['shape']=='circle')),
#   lambda x: x['color']=='green',
#   lambda x: (not (x['color']=='red') or not (x['color']=='green')),
#   lambda x: (not (x['color']=='green') or not (x['color']=='blue')),
#   lambda x: (x['shape']=='square' or x['shape']=='circle'),
#   lambda x: (not (x['color']=='blue') or not (x['color']=='red')),
#   lambda x: (not (x['shape']=='circle') or x['color']=='red'),
#   lambda x: (x['shape']=='square' or x['color']=='red'),
#   lambda x: (x['color']=='blue' or x['shape']=='square'),
#   lambda x: x['shape']=='square',
#   lambda x: (x['shape']=='circle' or not (x['color']=='green')),
#   lambda x: (not (x['shape']=='square') or not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='square') or not (x['shape']=='square')),
#   lambda x: (not (x['color']=='green') or x['color']=='blue'),
#   lambda x: (not (x['color']=='blue') or x['color']=='green'),
#   lambda x: (x['color']=='red' or not (x['shape']=='triangle')),
#   lambda x: (x['shape']=='triangle' or x['shape']=='triangle'),
#   lambda x: (not (x['shape']=='square') or x['shape']=='circle'),
#   lambda x: (x['shape']=='square' or not (x['color']=='green')),
#   lambda x: (not (x['shape']=='circle') or not (x['shape']=='square')),
#   lambda x: (x['shape']=='square' or not (x['shape']=='triangle')),
#   lambda x: (x['color']=='green' or not (x['shape']=='triangle')),
#   lambda x: (x['shape']=='circle' or x['color']=='green'),
#   lambda x: (not (x['shape']=='triangle') or not (x['color']=='red')),
#   lambda x: (x['color']=='green' or x['color']=='blue'),
#   lambda x: (x['color']=='blue' or x['color']=='green'),
#   lambda x: (not (x['shape']=='triangle') or x['color']=='red'),
#   lambda x: (not (x['shape']=='circle') or x['shape']=='triangle'),
#   lambda x: (x['color']=='green' or x['shape']=='square'),
#   lambda x: (x['color']=='green' or not (x['color']=='red')),
#   lambda x: (x['shape']=='square' or x['color']=='green'),
#   lambda x: x['shape']=='circle',
#   lambda x: (x['shape']=='circle' or x['shape']=='square'),
#   lambda x: (x['shape']=='triangle' or not (x['shape']=='square')),
#   lambda x: (not (x['color']=='blue') or not (x['shape']=='triangle')),
#   lambda x: (x['shape']=='circle' or not (x['shape']=='circle')),
#   lambda x: (not (x['color']=='red') or x['color']=='red'),
#   lambda x: (not (x['color']=='blue') or not (x['color']=='green')),
#   lambda x: (x['color']=='green' or not (x['shape']=='square')),
#   lambda x: (x['color']=='blue' or not (x['shape']=='triangle')),
#   lambda x: (x['shape']=='circle' or x['color']=='red'),
#   lambda x: (not (x['shape']=='square') or not (x['color']=='red')),
#   lambda x: (x['shape']=='triangle' or not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='circle') or not (x['shape']=='triangle')),
#   lambda x: (not (x['color']=='green') or not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='square') or not (x['color']=='blue')),
#   lambda x: (x['shape']=='triangle' or x['color']=='red'),
#   lambda x: (not (x['shape']=='square') or not (x['shape']=='triangle')),
#   lambda x: (not (x['color']=='red') or x['shape']=='triangle'),
#   lambda x: (x['color']=='green' or x['shape']=='triangle'),
#   lambda x: (x['shape']=='square' or not (x['color']=='blue')),
#   lambda x: (x['color']=='blue' or not (x['color']=='red')),
#   lambda x: (x['shape']=='triangle' or not (x['shape']=='triangle')),
#   lambda x: (not (x['color']=='green') or not (x['color']=='red')),
#   lambda x: (not (x['color']=='red') or x['shape']=='square'),
#   lambda x: (not (x['color']=='blue') or x['shape']=='circle'),
#   lambda x: (not (x['shape']=='triangle') or x['color']=='blue'),
#   lambda x: (not (x['color']=='green') or not (x['shape']=='triangle')),
#   lambda x: (x['color']=='red' or x['color']=='green'),
#   lambda x: (x['color']=='green' or not (x['shape']=='circle')),
#   lambda x: (not (x['color']=='blue') or x['color']=='blue'),
#   lambda x: (x['color']=='green' or not (x['color']=='green')),
#   lambda x: (x['shape']=='triangle' or x['shape']=='square'),
#   lambda x: (not (x['color']=='green') or x['shape']=='circle'),
#   lambda x: (not (x['color']=='green') or not (x['color']=='green')),
#   lambda x: x['color']=='blue',
#   lambda x: (x['color']=='red' or not (x['color']=='green')),
#   lambda x: not (x['color']=='green'),
#   lambda x: (x['shape']=='square' or x['color']=='blue'),
#   lambda x: (x['color']=='red' or not (x['shape']=='square')),
#   lambda x: (x['shape']=='triangle' or x['color']=='green'),
#   lambda x: (x['color']=='red' or x['color']=='red'),
#   lambda x: (not (x['shape']=='circle') or not (x['shape']=='circle')),
#   lambda x: (x['shape']=='square' or not (x['shape']=='square')),
#   lambda x: (x['shape']=='circle' or x['shape']=='triangle'),
#   lambda x: not (x['color']=='blue'),
#   lambda x: (not (x['color']=='blue') or not (x['shape']=='circle')),
#   lambda x: (x['shape']=='triangle' or x['shape']=='circle'),
#   lambda x: (x['color']=='blue' or x['color']=='blue'),
#   lambda x: (x['color']=='green' or x['color']=='green'),
#   lambda x: (not (x['shape']=='circle') or x['shape']=='square'),
#   lambda x: (not (x['color']=='blue') or not (x['color']=='blue')),
#   lambda x: (not (x['color']=='green') or not (x['shape']=='square')),
#   lambda x: (x['shape']=='triangle' or x['color']=='blue'),
#   lambda x: (not (x['color']=='red') or not (x['shape']=='square')),
#   lambda x: (not (x['shape']=='triangle') or x['shape']=='square'),
#   lambda x: (x['color']=='red' or not (x['shape']=='circle')),
#   lambda x: (x['shape']=='square' or x['shape']=='square'),
#   lambda x: x['shape']=='triangle',
#   lambda x: (x['shape']=='circle' or x['color']=='blue'),
#   lambda x: (not (x['color']=='blue') or x['color']=='red'),
#   lambda x: (x['color']=='blue' or not (x['color']=='green')),
#   lambda x: (x['color']=='red' or not (x['color']=='red')),
#   lambda x: (x['shape']=='triangle' or not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='square') or x['shape']=='triangle'),
#   lambda x: (x['color']=='blue' or not (x['shape']=='square')),
#   lambda x: (x['shape']=='circle' or not (x['shape']=='square')),
#   lambda x: (not (x['shape']=='square') or x['color']=='red'),
#   lambda x: not (x['shape']=='square'),
#   lambda x: (not (x['color']=='red') or x['shape']=='circle'),
#   lambda x: (not (x['shape']=='square') or x['color']=='blue'),
#   lambda x: (not (x['color']=='red') or not (x['color']=='red')),
#   lambda x: (not (x['shape']=='triangle') or not (x['color']=='blue')),
#   lambda x: (x['color']=='red' or x['color']=='blue'),
#   lambda x: (x['color']=='red' or not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='circle') or x['color']=='green'),
#   lambda x: (x['shape']=='triangle' or not (x['color']=='red')),
#   lambda x: x['color']=='red',
#   lambda x: (x['shape']=='circle' or not (x['shape']=='triangle')),
#   lambda x: not (x['shape']=='triangle'),
#   lambda x: (x['color']=='red' or x['shape']=='circle'),
#   lambda x: (x['shape']=='circle' or x['shape']=='circle'),
#   lambda x: (x['shape']=='circle' or not (x['color']=='blue')),
#   lambda x: not (x['shape']=='circle'),
#   lambda x: (not (x['color']=='blue') or not (x['shape']=='square')),
#   lambda x: (x['color']=='red' or x['shape']=='triangle'),
#   lambda x: (x['color']=='green' or x['shape']=='circle'),
#   lambda x: (not (x['shape']=='triangle') or x['shape']=='circle'),
#   lambda x: (x['shape']=='triangle' or not (x['color']=='green')),
#   lambda x: (x['color']=='red' or x['shape']=='square'),
#   lambda x: (x['color']=='blue' or x['color']=='red'),
#   lambda x: (not (x['shape']=='square') or x['shape']=='square'),
#   lambda x: (not (x['shape']=='triangle') or not (x['shape']=='triangle')),
#   lambda x: (not (x['shape']=='triangle') or x['color']=='green'),
#   lambda x: (x['color']=='blue' or x['shape']=='circle'),
#   lambda x: (not (x['color']=='red') or not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='triangle') or x['shape']=='triangle')],
#  6: [lambda x: (not (x['shape']=='circle') or (not (x['color']=='blue') or x['shape']=='circle')),
#   lambda x: (x['shape']=='square' and not (x['color']=='green')),
#   lambda x: (x['color']=='green' or x['color']=='red'),
#   lambda x: (not (x['color']=='blue') and x['color']=='red'),
#   lambda x: (not (x['color']=='blue') or (not (x['color']=='red') or not (x['shape']=='square'))),
#   lambda x: (x['shape']=='square' and x['color']=='blue'),
#   lambda x: (x['color']=='green' or not (x['color']=='blue')),
#   lambda x: (x['color']=='blue' and x['shape']=='square'),
#   lambda x: (not (x['shape']=='triangle') or (x['color']=='green' or x['shape']=='triangle')),
#   lambda x: (x['shape']=='square' and not (x['color']=='red')),
#   lambda x: (x['shape']=='square' or (x['color']=='red' or x['color']=='green')),
#   lambda x: (x['color']=='blue' or (x['color']=='blue' or x['color']=='green')),
#   lambda x: (x['shape']=='square' or (not (x['color']=='blue') or x['color']=='green')),
#   lambda x: (x['color']=='green' or (x['color']=='green' or x['color']=='red')),
#   lambda x: (not (x['shape']=='square') or not (x['color']=='green')),
#   lambda x: (x['shape']=='triangle' or (x['color']=='red' or x['color']=='blue')),
#   lambda x: (not (x['shape']=='triangle') and not (x['shape']=='triangle')),
#   lambda x: (x['shape']=='square' or (x['shape']=='triangle' or not (x['shape']=='circle'))),
#   lambda x: (not (x['shape']=='circle') or x['shape']=='circle'),
#   lambda x: (not (x['color']=='blue') or x['shape']=='square'),
#   lambda x: (not (x['shape']=='square') or (not (x['color']=='green') or x['shape']=='triangle')),
#   lambda x: (not (x['color']=='blue') and not (x['color']=='red')),
#   lambda x: (x['shape']=='circle' or not (x['color']=='red')),
#   lambda x: (not (x['color']=='green') or (not (x['color']=='blue') or x['color']=='green')),
#   lambda x: (not (x['shape']=='triangle') or not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='circle') and not (x['color']=='blue')),
#   lambda x: (x['color']=='blue' or not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='circle') or not (x['color']=='red')),
#   lambda x: (not (x['shape']=='triangle') or not (x['shape']=='square')),
#   lambda x: (x['color']=='red' or (not (x['shape']=='triangle') or not (x['color']=='red'))),
#   lambda x: (not (x['shape']=='triangle') or (not (x['color']=='green') or x['shape']=='circle')),
#   lambda x: (not (x['shape']=='circle') and x['shape']=='triangle'),
#   lambda x: (not (x['shape']=='triangle') or not (x['color']=='green')),
#   lambda x: (not (x['color']=='red') or not (x['shape']=='triangle')),
#   lambda x: (x['color']=='red' and not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='circle') or (not (x['color']=='red') or x['shape']=='square')),
#   lambda x: (not (x['shape']=='square') or (not (x['color']=='green') or not (x['shape']=='circle'))),
#   lambda x: (not (x['color']=='red') or (x['shape']=='square' or x['color']=='red')),
#   lambda x: (x['shape']=='triangle' or (not (x['color']=='red') or not (x['shape']=='triangle'))),
#   lambda x: (x['color']=='blue' or not (x['shape']=='circle')),
#   lambda x: (x['shape']=='triangle' or (not (x['color']=='blue') or not (x['shape']=='square'))),
#   lambda x: (not (x['color']=='green') or not (x['color']=='blue')),
#   lambda x: (x['color']=='green' and not (x['color']=='green')),
#   lambda x: (x['shape']=='circle' or (not (x['shape']=='square') or not (x['shape']=='triangle'))),
#   lambda x: (x['color']=='blue' or (not (x['shape']=='triangle') or not (x['shape']=='circle'))),
#   lambda x: (x['color']=='green' and x['shape']=='circle'),
#   lambda x: (not (x['color']=='blue') or not (x['color']=='red')),
#   lambda x: (x['shape']=='square' or x['shape']=='circle'),
#   lambda x: (x['shape']=='square' or x['color']=='red'),
#   lambda x: (x['color']=='green' or (x['color']=='green' or x['color']=='green')),
#   lambda x: (not (x['color']=='blue') or (not (x['shape']=='square') or not (x['shape']=='square'))),
#   lambda x: (not (x['color']=='red') or (not (x['color']=='green') or not (x['shape']=='circle'))),
#   lambda x: (x['color']=='green' or (not (x['shape']=='triangle') or x['shape']=='square')),
#   lambda x: (not (x['color']=='red') or (x['shape']=='circle' or not (x['color']=='red'))),
#   lambda x: (x['color']=='red' and not (x['shape']=='square')),
#   lambda x: (x['shape']=='triangle' or (not (x['shape']=='square') or not (x['shape']=='triangle'))),
#   lambda x: (not (x['shape']=='square') or not (x['shape']=='square')),
#   lambda x: (not (x['color']=='red') or (not (x['color']=='blue') or x['shape']=='square')),
#   lambda x: (x['color']=='red' or not (x['shape']=='triangle')),
#   lambda x: (not (x['color']=='red') or (not (x['color']=='red') or not (x['shape']=='square'))),
#   lambda x: (not (x['color']=='blue') and x['shape']=='square'),
#   lambda x: (not (x['color']=='green') and not (x['color']=='red')),
#   lambda x: (x['shape']=='square' or not (x['color']=='green')),
#   lambda x: (x['shape']=='square' or not (x['shape']=='triangle')),
#   lambda x: (x['shape']=='circle' or x['color']=='green'),
#   lambda x: (x['color']=='blue' and not (x['shape']=='triangle')),
#   lambda x: (x['color']=='blue' or (not (x['shape']=='triangle') or x['color']=='red')),
#   lambda x: (not (x['color']=='green') or (not (x['color']=='green') or not (x['shape']=='square'))),
#   lambda x: (x['color']=='blue' or x['color']=='green'),
#   lambda x: (not (x['shape']=='triangle') or (not (x['color']=='red') or not (x['color']=='blue'))),
#   lambda x: (not (x['shape']=='square') and not (x['shape']=='square')),
#   lambda x: (x['color']=='blue' or (x['color']=='blue' or not (x['shape']=='triangle'))),
#   lambda x: (not (x['color']=='blue') or (x['color']=='green' or x['shape']=='triangle')),
#   lambda x: (x['shape']=='square' and x['shape']=='circle'),
#   lambda x: (x['color']=='green' or x['shape']=='square'),
#   lambda x: (x['shape']=='triangle' and not (x['shape']=='triangle')),
#   lambda x: (not (x['color']=='red') or (x['shape']=='circle' or not (x['shape']=='triangle'))),
#   lambda x: (not (x['color']=='blue') and not (x['shape']=='circle')),
#   lambda x: (x['color']=='blue' or (x['shape']=='square' or not (x['color']=='red'))),
#   lambda x: (x['shape']=='circle' or (x['color']=='red' or x['color']=='red')),
#   lambda x: (x['shape']=='triangle' or (x['color']=='green' or x['shape']=='circle')),
#   lambda x: (not (x['color']=='green') or (x['shape']=='square' or x['color']=='blue')),
#   lambda x: (not (x['color']=='blue') or (not (x['shape']=='square') or not (x['color']=='green'))),
#   lambda x: (x['shape']=='square' and x['shape']=='square'),
#   lambda x: (x['shape']=='circle' or x['shape']=='square'),
#   lambda x: (not (x['shape']=='circle') and x['color']=='green'),
#   lambda x: (x['shape']=='triangle' or not (x['shape']=='square')),
#   lambda x: (x['shape']=='circle' and not (x['color']=='green')),
#   lambda x: (x['shape']=='circle' or (x['shape']=='triangle' or x['color']=='green')),
#   lambda x: (x['shape']=='circle' or not (x['shape']=='circle')),
#   lambda x: (x['shape']=='circle' and not (x['color']=='red')),
#   lambda x: (not (x['shape']=='triangle') and not (x['color']=='blue')),
#   lambda x: (x['color']=='red' and x['shape']=='circle'),
#   lambda x: (x['shape']=='circle' and x['shape']=='square'),
#   lambda x: (x['color']=='blue' and x['color']=='green'),
#   lambda x: (x['color']=='green' or not (x['shape']=='square')),
#   lambda x: (x['shape']=='circle' and x['color']=='red'),
#   lambda x: (x['color']=='green' or (x['color']=='red' or not (x['shape']=='square'))),
#   lambda x: (x['color']=='blue' or not (x['shape']=='triangle')),
#   lambda x: (not (x['color']=='green') and not (x['color']=='green')),
#   lambda x: (not (x['shape']=='square') or not (x['color']=='red')),
#   lambda x: (not (x['shape']=='circle') or not (x['shape']=='triangle')),
#   lambda x: (x['color']=='green' or (x['color']=='red' or not (x['shape']=='circle'))),
#   lambda x: (not (x['color']=='red') or x['shape']=='triangle'),
#   lambda x: (not (x['color']=='green') or not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='square') or not (x['color']=='blue')),
#   lambda x: (x['shape']=='triangle' and not (x['color']=='blue')),
#   lambda x: (x['color']=='green' or x['shape']=='triangle'),
#   lambda x: (not (x['color']=='green') or (x['shape']=='circle' or not (x['shape']=='triangle'))),
#   lambda x: (x['shape']=='circle' or (x['shape']=='triangle' or x['color']=='red')),
#   lambda x: (x['color']=='blue' or not (x['color']=='red')),
#   lambda x: (not (x['color']=='red') and x['color']=='green'),
#   lambda x: (not (x['color']=='red') or (not (x['shape']=='circle') or x['shape']=='triangle')),
#   lambda x: (x['shape']=='triangle' or not (x['shape']=='triangle')),
#   lambda x: (not (x['color']=='green') or (x['color']=='red' or not (x['shape']=='square'))),
#   lambda x: (not (x['shape']=='triangle') or (x['color']=='blue' or not (x['shape']=='circle'))),
#   lambda x: (not (x['color']=='green') or not (x['color']=='red')),
#   lambda x: (x['shape']=='circle' and not (x['shape']=='square')),
#   lambda x: (x['color']=='red' and not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='circle') or (x['shape']=='circle' or x['color']=='red')),
#   lambda x: (x['color']=='red' and not (x['color']=='green')),
#   lambda x: (x['color']=='green' or (x['shape']=='square' or x['color']=='blue')),
#   lambda x: (x['color']=='blue' or (x['shape']=='square' or not (x['shape']=='circle'))),
#   lambda x: (not (x['shape']=='square') and x['shape']=='circle'),
#   lambda x: (not (x['color']=='blue') or (not (x['color']=='blue') or x['shape']=='triangle')),
#   lambda x: (not (x['color']=='blue') or x['shape']=='circle'),
#   lambda x: (not (x['shape']=='circle') or (x['shape']=='circle' or not (x['color']=='blue'))),
#   lambda x: (not (x['color']=='blue') or (x['color']=='red' or not (x['shape']=='triangle'))),
#   lambda x: (not (x['color']=='green') or not (x['shape']=='triangle')),
#   lambda x: (not (x['shape']=='triangle') or x['color']=='blue'),
#   lambda x: (x['color']=='red' or x['color']=='green'),
#   lambda x: (x['color']=='green' or not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='square') and x['color']=='green'),
#   lambda x: (not (x['shape']=='square') or (not (x['shape']=='circle') or x['color']=='red')),
#   lambda x: (not (x['shape']=='square') or (not (x['color']=='red') or x['color']=='blue')),
#   lambda x: (x['color']=='green' and not (x['shape']=='circle')),
#   lambda x: (x['shape']=='triangle' and not (x['shape']=='circle')),
#   lambda x: (x['color']=='green' and x['color']=='green'),
#   lambda x: (not (x['color']=='green') or (x['shape']=='square' or not (x['shape']=='triangle'))),
#   lambda x: (not (x['shape']=='circle') or (not (x['shape']=='circle') or x['color']=='red')),
#   lambda x: (not (x['color']=='red') or (not (x['color']=='green') or x['shape']=='circle')),
#   lambda x: (not (x['shape']=='circle') and not (x['color']=='red')),
#   lambda x: (x['shape']=='triangle' and not (x['color']=='red')),
#   lambda x: (not (x['color']=='red') or (x['shape']=='triangle' or not (x['color']=='blue'))),
#   lambda x: (not (x['color']=='green') and not (x['shape']=='triangle')),
#   lambda x: (x['shape']=='triangle' or x['shape']=='square'),
#   lambda x: (x['color']=='blue' and not (x['color']=='blue')),
#   lambda x: (not (x['color']=='green') or x['shape']=='circle'),
#   lambda x: (not (x['color']=='blue') or (x['color']=='red' or not (x['color']=='blue'))),
#   lambda x: (not (x['shape']=='triangle') or (not (x['shape']=='circle') or x['shape']=='triangle')),
#   lambda x: (not (x['color']=='green') or (not (x['color']=='red') or x['color']=='red')),
#   lambda x: (x['color']=='blue' or (x['shape']=='circle' or not (x['shape']=='circle'))),
#   lambda x: (not (x['shape']=='circle') or (not (x['shape']=='triangle') or not (x['color']=='red'))),
#   lambda x: (not (x['color']=='green') or not (x['color']=='green')),
#   lambda x: (x['color']=='red' or (x['color']=='blue' or not (x['shape']=='circle'))),
#   lambda x: (x['color']=='red' or not (x['color']=='green')),
#   lambda x: (not (x['color']=='red') or (x['shape']=='circle' or x['color']=='blue')),
#   lambda x: (not (x['shape']=='triangle') and x['color']=='red'),
#   lambda x: (x['shape']=='square' or (not (x['shape']=='triangle') or not (x['color']=='red'))),
#   lambda x: (x['color']=='blue' and x['color']=='blue'),
#   lambda x: (x['shape']=='triangle' or (not (x['color']=='blue') or x['color']=='green')),
#   lambda x: (x['color']=='green' and not (x['shape']=='square')),
#   lambda x: (not (x['color']=='red') or (x['color']=='blue' or not (x['color']=='green'))),
#   lambda x: (x['shape']=='circle' or (not (x['shape']=='square') or not (x['color']=='green'))),
#   lambda x: (x['shape']=='square' or (x['color']=='blue' or not (x['color']=='red'))),
#   lambda x: (not (x['shape']=='square') or (x['color']=='blue' or not (x['shape']=='triangle'))),
#   lambda x: (not (x['shape']=='circle') and not (x['shape']=='circle')),
#   lambda x: (x['shape']=='triangle' or x['color']=='green'),
#   lambda x: (x['color']=='red' or x['color']=='red'),
#   lambda x: (not (x['color']=='green') or (not (x['shape']=='circle') or x['color']=='red')),
#   lambda x: (x['shape']=='square' and not (x['shape']=='circle')),
#   lambda x: (x['color']=='green' or (x['color']=='red' or x['shape']=='circle')),
#   lambda x: (x['color']=='green' or (not (x['color']=='blue') or x['color']=='red')),
#   lambda x: (x['shape']=='circle' or (not (x['color']=='blue') or x['shape']=='square')),
#   lambda x: (not (x['shape']=='square') or (x['color']=='green' or not (x['color']=='green'))),
#   lambda x: (x['color']=='green' and not (x['shape']=='triangle')),
#   lambda x: (not (x['shape']=='square') or (x['color']=='blue' or not (x['color']=='red'))),
#   lambda x: (x['shape']=='circle' or x['shape']=='triangle'),
#   lambda x: (not (x['shape']=='triangle') or (not (x['shape']=='triangle') or x['color']=='red')),
#   lambda x: (not (x['color']=='blue') or not (x['shape']=='circle')),
#   lambda x: (x['color']=='blue' or x['color']=='blue'),
#   lambda x: (not (x['color']=='blue') and not (x['color']=='green')),
#   lambda x: (x['color']=='green' and x['color']=='red'),
#   lambda x: (not (x['shape']=='triangle') and x['shape']=='square'),
#   lambda x: (not (x['shape']=='circle') or x['shape']=='square'),
#   lambda x: (not (x['color']=='blue') or not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='square') and not (x['color']=='green')),
#   lambda x: (not (x['shape']=='triangle') or (x['color']=='green' or not (x['shape']=='circle'))),
#   lambda x: (x['color']=='blue' or (x['shape']=='triangle' or x['shape']=='circle')),
#   lambda x: (not (x['shape']=='square') or (not (x['color']=='green') or x['color']=='green')),
#   lambda x: (not (x['shape']=='triangle') and x['color']=='green'),
#   lambda x: (not (x['color']=='red') and not (x['shape']=='square')),
#   lambda x: (x['color']=='red' and not (x['color']=='red')),
#   lambda x: (not (x['shape']=='square') or (x['shape']=='triangle' or x['color']=='red')),
#   lambda x: (not (x['shape']=='triangle') or x['shape']=='square'),
#   lambda x: (x['color']=='red' or (x['color']=='green' or x['color']=='blue')),
#   lambda x: (x['color']=='blue' and x['shape']=='triangle'),
#   lambda x: (x['shape']=='circle' or (x['shape']=='circle' or x['shape']=='triangle')),
#   lambda x: (x['shape']=='square' or x['shape']=='square'),
#   lambda x: (not (x['color']=='red') and not (x['color']=='green')),
#   lambda x: (not (x['shape']=='circle') or (x['shape']=='circle' or not (x['shape']=='circle'))),
#   lambda x: (not (x['shape']=='triangle') or (not (x['color']=='green') or not (x['color']=='red'))),
#   lambda x: (not (x['color']=='blue') or x['color']=='red'),
#   lambda x: (x['color']=='blue' or not (x['color']=='green')),
#   lambda x: (not (x['shape']=='triangle') and x['shape']=='circle'),
#   lambda x: (not (x['shape']=='triangle') or (x['color']=='green' or x['shape']=='circle')),
#   lambda x: (x['color']=='blue' or not (x['shape']=='square')),
#   lambda x: (x['shape']=='triangle' or not (x['color']=='blue')),
#   lambda x: (x['shape']=='square' and not (x['shape']=='square')),
#   lambda x: (x['shape']=='circle' or not (x['shape']=='square')),
#   lambda x: (x['shape']=='triangle' and x['shape']=='square'),
#   lambda x: (not (x['shape']=='square') or x['color']=='red'),
#   lambda x: (x['color']=='blue' and not (x['color']=='red')),
#   lambda x: (not (x['shape']=='triangle') or (x['shape']=='circle' or not (x['color']=='green'))),
#   lambda x: (not (x['color']=='red') or x['shape']=='circle'),
#   lambda x: (not (x['shape']=='triangle') and not (x['color']=='red')),
#   lambda x: (not (x['color']=='green') and x['shape']=='circle'),
#   lambda x: (not (x['shape']=='square') and not (x['shape']=='circle')),
#   lambda x: (x['color']=='blue' and not (x['shape']=='circle')),
#   lambda x: (not (x['shape']=='square') or x['color']=='blue'),
#   lambda x: (x['shape']=='square' or (x['color']=='red' or x['shape']=='triangle')),
#   lambda x: (x['color']=='red' or x['color']=='blue'),
#   lambda x: (not (x['shape']=='circle') and x['color']=='blue'),
#   lambda x: (not (x['color']=='red') and not (x['color']=='red')),
#   lambda x: (not (x['color']=='red') and x['color']=='blue'),
#   lambda x: (not (x['shape']=='square') or (not (x['shape']=='circle') or x['color']=='green')),
#   lambda x: (x['shape']=='triangle' or not (x['color']=='red')),
#   lambda x: (not (x['color']=='green') or (not (x['color']=='blue') or x['shape']=='square')),
#   lambda x: (x['shape']=='circle' or x['shape']=='circle'),
#   lambda x: (x['shape']=='triangle' and x['shape']=='triangle'),
#   lambda x: (not (x['color']=='green') and not (x['shape']=='square')),
#   lambda x: (not (x['color']=='red') and not (x['shape']=='circle')),
#   lambda x: (not (x['color']=='blue') or not (x['shape']=='square')),
#   lambda x: (x['color']=='red' or x['shape']=='triangle'),
#   lambda x: (x['color']=='blue' or (not (x['color']=='blue') or not (x['shape']=='triangle'))),
#   lambda x: (not (x['shape']=='square') or (x['shape']=='circle' or not (x['color']=='red'))),
#   lambda x: (not (x['shape']=='square') and x['color']=='blue'),
#   lambda x: (x['color']=='red' or x['shape']=='square'),
#   lambda x: (x['color']=='red' or (x['shape']=='square' or not (x['color']=='red'))),
#   lambda x: (not (x['color']=='red') and x['shape']=='triangle'),
#   lambda x: (not (x['shape']=='square') or x['shape']=='square'),
#   lambda x: (not (x['shape']=='circle') and not (x['shape']=='triangle')),
#   lambda x: (not (x['shape']=='triangle') or (not (x['shape']=='circle') or x['color']=='red')),
#   lambda x: (not (x['shape']=='triangle') and not (x['shape']=='circle')),
#   lambda x: (not (x['color']=='blue') and not (x['color']=='blue')),
#   lambda x: (not (x['shape']=='triangle') or (x['shape']=='triangle' or not (x['shape']=='circle'))),
#   lambda x: (x['color']=='green' and not (x['color']=='blue')),
#   lambda x: (not (x['color']=='green') and x['color']=='blue'),
#   lambda x: (not (x['color']=='green') or (not (x['shape']=='square') or x['shape']=='circle')),
#   lambda x: (not (x['shape']=='triangle') or x['color']=='green'),
#   lambda x: (not (x['shape']=='square') or (not (x['color']=='red') or not (x['color']=='blue'))),
#   lambda x: (not (x['shape']=='circle') or (not (x['color']=='red') or not (x['shape']=='circle'))),
#   lambda x: (not (x['shape']=='circle') or (x['color']=='red' or not (x['color']=='red'))),
#   lambda x: (not (x['shape']=='square') or (not (x['shape']=='circle') or not (x['color']=='blue'))),
#   lambda x: (x['shape']=='circle' or (not (x['shape']=='square') or x['shape']=='triangle')),
#   lambda x: (x['color']=='blue' or (x['shape']=='circle' or x['shape']=='circle'))],
#  7: [lambda x: (not (x['color']=='green') or (not (x['color']=='blue') and x['shape']=='square')),
#   lambda x: (x['color']=='green' and (not (x['shape']=='triangle') and x['color']=='blue')),
#   lambda x: (x['color']=='red' and (x['color']=='blue' and not (x['shape']=='triangle'))),
#   lambda x: (x['shape']=='circle' or (x['shape']=='circle' and not (x['color']=='green'))),
#   lambda x: (x['color']=='green' or (x['color']=='blue' or x['shape']=='circle')),
#   lambda x: (x['shape']=='circle' or (not (x['shape']=='triangle') or not (x['shape']=='square'))),
#   lambda x: (not (x['color']=='green') or (not (x['shape']=='circle') or (not (x['shape']=='square') or x['shape']=='square'))),
#   lambda x: (not (x['shape']=='circle') or (x['shape']=='circle' and x['color']=='red')),
#   lambda x: (not (x['shape']=='circle') or (x['shape']=='square' or (not (x['color']=='blue') or not (x['color']=='green')))),
#   lambda x: (x['shape']=='circle' or (x['color']=='green' or (not (x['shape']=='circle') or x['color']=='green'))),
#   lambda x: (not (x['shape']=='square') or (x['shape']=='square' and x['color']=='blue')),
#   lambda x: (not (x['color']=='blue') and (not (x['shape']=='square') and x['color']=='blue')),
#   lambda x: (not (x['color']=='green') or (x['shape']=='circle' or x['shape']=='triangle')),
#   lambda x: (not (x['color']=='green') or (not (x['shape']=='triangle') and not (x['shape']=='square'))),
#   lambda x: (x['shape']=='triangle' and (not (x['shape']=='triangle') and x['color']=='blue')),
#   lambda x: (not (x['color']=='red') or (not (x['shape']=='square') and not (x['color']=='blue'))),
#   lambda x: (x['color']=='blue' and (not (x['shape']=='square') and x['shape']=='circle')),
#   lambda x: (not (x['color']=='green') and (not (x['shape']=='square') and not (x['shape']=='triangle'))),
#   lambda x: (x['color']=='green' or (not (x['color']=='red') or x['color']=='green')),
#   lambda x: (not (x['color']=='blue') and (x['color']=='blue' and not (x['shape']=='circle'))),
#   lambda x: (x['color']=='green' or (x['shape']=='square' and x['shape']=='square')),
#   lambda x: (x['color']=='blue' and (not (x['color']=='red') and not (x['shape']=='square'))),
#   lambda x: (x['shape']=='square' or (x['color']=='blue' and x['color']=='red')),
#   lambda x: (x['color']=='green' or (x['color']=='green' or (x['color']=='blue' or x['color']=='green'))),
#   lambda x: (x['color']=='red' and (x['shape']=='square' and x['color']=='green')),
#   lambda x: (not (x['shape']=='square') or (x['shape']=='square' or (not (x['color']=='green') or not (x['color']=='red')))),
#   lambda x: (not (x['color']=='green') and (not (x['shape']=='square') and x['color']=='green')),
#   lambda x: (x['shape']=='circle' or (not (x['color']=='blue') or not (x['shape']=='circle'))),
#   lambda x: (x['color']=='green' or (x['shape']=='square' or (not (x['color']=='red') or not (x['color']=='blue')))),
#   lambda x: (not (x['shape']=='circle') and (not (x['shape']=='circle') and x['color']=='blue')),
#   lambda x: (x['shape']=='square' or (x['color']=='blue' or (x['color']=='green' or not (x['shape']=='square')))),
#   lambda x: (not (x['shape']=='triangle') or (x['shape']=='circle' and not (x['shape']=='circle'))),
#   lambda x: (not (x['shape']=='circle') and (x['shape']=='triangle' and not (x['shape']=='circle'))),
#   lambda x: (not (x['color']=='blue') or (not (x['color']=='blue') or not (x['color']=='green'))),
#   lambda x: (not (x['shape']=='square') or (x['color']=='green' or x['shape']=='triangle')),
#   lambda x: (x['shape']=='circle' or (not (x['shape']=='triangle') or not (x['color']=='green'))),
#   lambda x: (not (x['color']=='blue') or (x['shape']=='square' or x['shape']=='square')),
#   lambda x: (x['shape']=='square' and (x['shape']=='circle' and x['shape']=='triangle')),
#   lambda x: (not (x['shape']=='square') and (x['shape']=='square' and x['shape']=='circle')),
#   lambda x: (not (x['color']=='blue') or (not (x['color']=='green') and not (x['shape']=='triangle'))),
#   lambda x: (x['shape']=='square' or (x['shape']=='circle' and not (x['color']=='blue'))),
#   lambda x: (x['color']=='red' or (not (x['color']=='green') or x['shape']=='circle')),
#   lambda x: (not (x['shape']=='square') or (x['shape']=='triangle' or (x['shape']=='triangle' or not (x['shape']=='square')))),
#   lambda x: (not (x['shape']=='circle') and (not (x['color']=='red') and not (x['shape']=='square'))),
#   lambda x: (x['color']=='red' or (x['shape']=='triangle' or (x['color']=='blue' or not (x['color']=='red')))),
#   lambda x: (not (x['color']=='green') or (not (x['color']=='blue') or x['shape']=='circle')),
#   lambda x: (x['color']=='red' or (not (x['shape']=='circle') or x['shape']=='triangle')),
#   lambda x: (x['shape']=='triangle' and (not (x['color']=='green') and not (x['color']=='blue'))),
#   lambda x: (x['shape']=='triangle' and (not (x['shape']=='triangle') and x['color']=='green')),
#   lambda x: (x['color']=='red' or (x['color']=='green' or x['shape']=='circle')),
#   lambda x: (not (x['shape']=='circle') or (not (x['shape']=='circle') or (not (x['shape']=='circle') or x['color']=='green'))),
#   lambda x: (not (x['color']=='green') or (x['color']=='red' and x['color']=='blue')),
#   lambda x: (x['shape']=='triangle' or (not (x['color']=='green') or x['color']=='blue')),
#   lambda x: (x['shape']=='circle' or (not (x['color']=='red') or (not (x['shape']=='triangle') or not (x['color']=='red')))),
#   lambda x: (x['shape']=='triangle' and (not (x['shape']=='triangle') and x['color']=='red')),
#   lambda x: (x['shape']=='circle' and (not (x['color']=='green') and x['shape']=='square')),
#   lambda x: (x['shape']=='square' or (not (x['color']=='green') and not (x['color']=='blue'))),
#   lambda x: (x['color']=='red' or (not (x['color']=='blue') or x['color']=='red')),
#   lambda x: (x['shape']=='circle' or (not (x['color']=='blue') or not (x['color']=='green'))),
#   lambda x: (x['shape']=='square' or (x['shape']=='triangle' or not (x['color']=='red'))),
#   lambda x: (x['color']=='green' and (not (x['shape']=='square') and x['color']=='blue')),
#   lambda x: (x['color']=='blue' or (x['shape']=='circle' and not (x['shape']=='triangle')))],
#  8: [lambda x: (x['shape']=='triangle' or (x['shape']=='square' or (not (x['shape']=='circle') or (not (x['shape']=='triangle') or not (x['shape']=='triangle'))))),
#   lambda x: (x['color']=='green' or (x['shape']=='square' and (x['color']=='blue' and not (x['shape']=='square')))),
#   lambda x: (x['color']=='blue' or (x['shape']=='triangle' and (x['color']=='green' and not (x['shape']=='circle')))),
#   lambda x: (x['shape']=='circle' or (not (x['color']=='blue') or (x['color']=='green' or (x['color']=='red' or x['color']=='red')))),
#   lambda x: (not (x['shape']=='square') or (not (x['shape']=='square') or (not (x['color']=='blue') and not (x['shape']=='square')))),
#   lambda x: (x['color']=='blue' or (not (x['shape']=='circle') or (x['color']=='blue' and not (x['color']=='green')))),
#   lambda x: (not (x['color']=='green') and (x['shape']=='triangle' and (not (x['color']=='blue') and not (x['color']=='red')))),
#   lambda x: (not (x['shape']=='square') or (x['shape']=='square' or (not (x['color']=='green') or x['color']=='green'))),
#   lambda x: (not (x['color']=='green') or (x['shape']=='square' and (x['shape']=='square' and not (x['shape']=='square')))),
#   lambda x: (not (x['color']=='red') or (x['shape']=='circle' or (x['color']=='blue' or (not (x['color']=='green') or not (x['color']=='green'))))),
#   lambda x: (not (x['color']=='blue') or (x['shape']=='circle' or (not (x['shape']=='circle') and x['color']=='red'))),
#   lambda x: (x['shape']=='square' or (x['color']=='blue' or (x['shape']=='triangle' or x['color']=='red')))],
#  9: [],
#  10: [lambda x: (x['shape']=='circle' or (x['shape']=='triangle' or (x['color']=='green' or (not (x['shape']=='square') or (not (x['shape']=='triangle') and x['color']=='red')))))],
#  11: [],
#  12: [],
#  13: [],
#  14: []}

# %%
import pandas as pd

# %%
for x in rules:
    rules[x] = len(rules[x])

# %%
rules
# Out:
# {0: 2,
#  1: 0,
#  2: 0,
#  3: 12,
#  4: 12,
#  5: 155,
#  6: 256,
#  7: 62,
#  8: 12,
#  9: 0,
#  10: 1,
#  11: 0,
#  12: 0,
#  13: 0,
#  14: 0}

# %%
plt.bar(rules.keys(), rules.values())
# Out:
# <BarContainer object of 15 artists>

# %%
rules2 = set()
for _ in range(100000):
    #rule = grammar.generate()
    #log_prob = grammar.log_probability(rule)
    rule2 = LOTHypothesis(grammar=grammar)
    rules2.add(rule2)
